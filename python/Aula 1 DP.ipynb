# %% [markdown]
# Aula 1

# %%
nome = "Lassu"
print(nome)
# Out:
# Lassu

# %%
print(type(nome))
# Out:
# <class 'str'>

# %%
nome
# Out:
# 'Lassu'

# %%
numero1 = 2
numero2 = 3

# %%
type(numero1)
# Out:
# int

# %%
soma = numero1 + numero2

# %%
print(soma)
# Out:
# 5

# %%
multiplicacao = numero1 * numero2

# %%
print(multiplicacao)
# Out:
# 6

# %%
divisao = numero2 / numero1

# %%
print(divisao)
# Out:
# 1.5

# %%
resto = numero1 % numero2

# %%
print(resto)
# Out:
# 2

# %%
expoente = numero1**2

# %%
print(expoente)
# Out:
# 4

# %% [markdown]
# ##DIFERENTE OP COMPARAÇÃO

# %%
numero3 = 7
numero4 = 2

# %%
numero3 > numero4
# Out:
# True

# %%
numero3 >= numero4
# Out:
# True

# %%
numero3 <= numero4
# Out:
# False

# %%
numero3 == numero4
# Out:
# False

# %%
numero3 != numero4
# Out:
# True

# %% [markdown]
# ## OP LÓGICOS

# %%
(numero3 != numero4) and (numero3 > numero4)
# Out:
# True

# %%
(numero3 == numero4) and (numero3 > numero4)
# Out:
# False

# %%
(numero3 >= numero4) or (numero3 <= numero4)
# Out:
# True

# %%
(numero3 >= numero4) or (numero3 != numero4)
# Out:
# True

# %%
not (numero3 > numero4) or (numero3 == numero4)
# Out:
# False

# %%
numero3 <= numero4
# Out:
# False

# %%
not (numero3 <= numero4)
# Out:
# True
